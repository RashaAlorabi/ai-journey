# %% [markdown]
# # 📁 التعامل مع الملفات (Files + CSV + Images)
#
# يشمل:
# - قراءة وكتابة الملفات
# - CSV
# - Dict + Sorting
# - التعامل مع الصور

# %% [markdown]
# ## 1️⃣ إدخال أسماء في List

# %%
names = []
for _ in range(3):
    names.append(input("What's your name? "))

for name in sorted(names):
    print(f"hello, {name}")
# Out:
# hello, a
# hello, al
# hello, rasha

# %% [markdown]
# ## 2️⃣ الكتابة في ملف

# %%
name = input("What's your name? ")

with open("names.txt", "a") as file:
    file.write(f"{name}\n")

# %% [markdown]
# ## 3️⃣ قراءة من ملف

# %%
with open("names.txt") as file:
    for line in file:
        print("hello,", line.strip())
# Out:
# hello, rasha

# %% [markdown]
# ## 4️⃣ قراءة CSV بسيط

# %%
with open("students0.csv") as file:
    for line in file:
        name, house = line.strip().split(",")
        print(f"{name} is in {house}")
# Out:
# Hermione is in Gryffindor
# Harry is in Gryffindor
# Ron is in Gryffindor
# Draco is in Slytherin

# %% [markdown]
# ## 5️⃣ استخدام Dictionary

# %%
students = []

with open("students0.csv") as file:
    for line in file:
        name, house = line.strip().split(",")
        students.append({"name": name, "house": house})

for student in students:
    print(f"{student['name']} is in {student['house']}")
# Out:
# Hermione is in Gryffindor
# Harry is in Gryffindor
# Ron is in Gryffindor
# Draco is in Slytherin

# %% [markdown]
# ## 6️⃣ Sorting باستخدام lambda

# %%
for student in sorted(students, key=lambda s: s["name"]):
    print(f"{student['name']} is in {student['house']}")
# Out:
# Draco is in Slytherin
# Harry is in Gryffindor
# Hermione is in Gryffindor
# Ron is in Gryffindor

# %% [markdown]
# ## 7️⃣ csv module

# %%
import csv

students = []

with open("students2.csv") as file:
    reader = csv.DictReader(file)
    for row in reader:
        students.append({"name": row["name"], "home": row["home"]})

for student in sorted(students, key=lambda s: s["name"]):
    print(f"{student['name']} is from {student['home']}")
# Out:
# Draco is from Malfoy Manor
# Harry is from Number Four, Privet Drive
# Ron is from The Burrow

# %% [markdown]
# ## 8️⃣ كتابة CSV

# %%
import csv

name = input("What's your name? ")
home = input("Where's your home? ")

with open("students2.csv", "a") as file:
    writer = csv.DictWriter(file, fieldnames=["name", "home"])
    writer.writerow({"name": name, "home": home})

# %% [markdown]
# ## 9️⃣ التعامل مع الصور (Pillow)

# %%
import sys
from PIL import Image

images = []

# مثال (تحتاج صور فعلية)
# images.append(Image.open("image1.png"))
# images.append(Image.open("image2.png"))

# images[0].save("output.gif", save_all=True, append_images=images[1:], duration=200, loop=0)
